# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
Tajmahal=Image.open(r"C:\Users\Dell\Downloads\tajmahal.jpg")
Tajmahal
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x340>

# %%
ones_arr=np.ones((3,3))
ones_arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones_arr*255
# Out:
# array([[255., 255., 255.],
#        [255., 255., 255.],
#        [255., 255., 255.]])

# %%
ones_arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
Tajmahal=Image.open(r"C:\Users\Dell\Downloads\tajmahal.jpg")
Tajmahal
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x340>

# %%
type(Tajmahal)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
Tajmahal_arr=np.asarray(Tajmahal)
Tajmahal_arr
# Out:
# array([[[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        [[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        [[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        ...,
#
#        [[ 33,  31,  34],
#         [ 36,  34,  35],
#         [ 29,  27,  28],
#         ...,
#         [ 15,  14,  10],
#         [ 10,   9,   5],
#         [ 13,  13,  11]],
#
#        [[ 18,  16,  19],
#         [ 31,  29,  30],
#         [ 32,  30,  31],
#         ...,
#         [ 33,  32,  28],
#         [ 28,  27,  23],
#         [ 24,  24,  22]],
#
#        [[ 16,  14,  17],
#         [ 24,  22,  23],
#         [ 23,  21,  22],
# ...

# %%
Tajmahal_arr.shape
# Out:
# (340, 510, 3)

# %%
type(Tajmahal_arr)
# Out:
# numpy.ndarray

# %%
Tajmahal_red=Tajmahal_arr.copy()
Tajmahal_red
# Out:
# array([[[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        [[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        [[ 88, 144, 161],
#         [ 88, 144, 161],
#         [ 88, 144, 161],
#         ...,
#         [ 76, 125, 140],
#         [ 76, 125, 140],
#         [ 76, 125, 140]],
#
#        ...,
#
#        [[ 33,  31,  34],
#         [ 36,  34,  35],
#         [ 29,  27,  28],
#         ...,
#         [ 15,  14,  10],
#         [ 10,   9,   5],
#         [ 13,  13,  11]],
#
#        [[ 18,  16,  19],
#         [ 31,  29,  30],
#         [ 32,  30,  31],
#         ...,
#         [ 33,  32,  28],
#         [ 28,  27,  23],
#         [ 24,  24,  22]],
#
#        [[ 16,  14,  17],
#         [ 24,  22,  23],
#         [ 23,  21,  22],
# ...

# %%
Tajmahal_arr==Tajmahal_red
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.imshow(Tajmahal_red)
plt.show()

# %%
Tajmahal_red.shape
# Out:
# (340, 510, 3)

# %%
plt.imshow(Tajmahal_red[:,:,0])
plt.show()

# %%
Tajmahal_red[:,:,0]
# Out:
# array([[88, 88, 88, ..., 76, 76, 76],
#        [88, 88, 88, ..., 76, 76, 76],
#        [88, 88, 88, ..., 76, 76, 76],
#        ...,
#        [33, 36, 29, ..., 15, 10, 13],
#        [18, 31, 32, ..., 33, 28, 24],
#        [16, 24, 23, ..., 31, 29, 33]], dtype=uint8)

# %%
plt.imshow(Tajmahal_red[:,:,0],cmap='Greys')
plt.show()

# %%
plt.imshow(Tajmahal_red[:,:,0],cmap='grey')
plt.show()

# %%
plt.imshow(Tajmahal_red[:,:,0], cmap='gist_yarg')
plt.show()

# %%
Tajmahal_red[:,:,0]
# Out:
# array([[88, 88, 88, ..., 76, 76, 76],
#        [88, 88, 88, ..., 76, 76, 76],
#        [88, 88, 88, ..., 76, 76, 76],
#        ...,
#        [33, 36, 29, ..., 15, 10, 13],
#        [18, 31, 32, ..., 33, 28, 24],
#        [16, 24, 23, ..., 31, 29, 33]], dtype=uint8)

# %%
plt.imshow(Tajmahal_red[:,:,0], cmap
